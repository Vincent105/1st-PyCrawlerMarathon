# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

request = requests.get('https://api.github.com/events')
request.text
# Out:
# kubernetes/repos","events_url":"https://api.github.com/users/kubernetes/events{/privacy}","received_events_url":"https://api.github.com/users/kubernetes/received_events","type":"Organization","site_admin":false},"repo":{"id":56353740,"node_id":"MDEwOlJlcG9zaXRvcnk1NjM1Mzc0MA==","name":"minikube","full_name":"kubernetes/minikube","private":false,"owner":{"login":"kubernetes","id":13629408,"node_id":"MDEyOk9yZ2FuaXphdGlvbjEzNjI5NDA4","avatar_url":"https://avatars2.githubusercontent.com/u/13629408?v=4","gravatar_id":"","url":"https://api.github.com/users/kubernetes","html_url":"https://github.com/kubernetes","followers_url":"https://api.github.com/users/kubernetes/followers","following_url":"https://api.github.com/users/kubernetes/following{/other_user}","gists_url":"https://api.github.com/users/kubernetes/gists{/gist_id}","starred_url":"https://api.github.com/users/kubernetes/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/kubernetes/subscriptions","organizations_url":"https://api.github.com/users/kubernetes/orgs","repos_url":"https://api.github.com/users/kubernetes/repos","events_url":"https://api.github.com/users/kubernetes/events{/privacy}","received_events_url":"https://api.github.com/users/kubernetes/received_events","type":"Organization","site_admin":false},"html_url":"https://github.com/kubernetes/minikube","description":"Run Kubernetes locally","fork":false,"url":"https://api.github.com/repos/kubernetes/minikube","forks_url":"https://api.github.com/repos/kubernetes/minikube/forks","keys_url":"https://api.github.com/repos/kubernetes/minikube/keys{/key_id}","collaborators_url":"https://api.github.com/repos/kubernetes/minikube/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/kubernetes/minikube/teams","hooks_url":"https://api.github.com/repos/kubernetes/minikube/hooks","issue_events_url":"https://api.github.com/repos/kubernetes/minikube/issues/events{/number}","events_url":"https://api.github.com/repos/kubernetes/minikube/events","assignees_url":"https://api.github.com/repos/kubernetes/minikube/assignees{/user}","branches_url":"https://api.github.com/repos/kubernetes/minikube/branches{/branch}","tags_url":"https://api.github.com/repos/kubernetes/minikube/tags","blobs_url":"https://api.github.com/repos/kubernetes/minikube/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/kubernetes/minikube/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/kubernetes/minikube/git/refs{/sha}","trees_url":"https://api.github.com/repos/kubernetes/minikube/git/trees{/sha}","statuses_url":"https://api.github.com/repos/kubernetes/minikube/statuses/{sha}","languages_url":"https://api.github.com/repos/kubernetes/minikube/languages","stargazers_url":"https://api.github.com/repos/kubernetes/minikube/stargazers","contributors_url":"https://api.github.com/repos/kubernetes/minikube/contributors","subscribers_url":"https://api.github.com/repos/kubernetes/minikube/subscribers","subscription_url":"https://api.github.com/repos/kubernetes/minikube/subscription","commits_url":"https://api.github.com/repos/kubernetes/minikube/commits{/sha}","git_commits_url":"https://api.github.com/repos/kubernetes/minikube/git/commits{/sha}","comments_url":"https://api.github.com/repos/kubernetes/minikube/comments{/number}","issue_comment_url":"https://api.github.com/repos/kubernetes/minikube/issues/comments{/number}","contents_url":"https://api.github.com/repos/kubernetes/minikube/contents/{+path}","compare_url":"https://api.github.com/repos/kubernetes/minikube/compare/{base}...{head}","merges_url":"https://api.github.com/repos/kubernetes/minikube/merges","archive_url":"https://api.github.com/repos/kubernetes/minikube/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/kubernetes/minikube/downloads","issues_url":"https://api.github.com/repos/kubernetes/minikube/issues{/number}","pulls_url":"https://api.github.com/repos/kubernetes/minikube/pulls{/number}","milestones_url":"https://api.git ...

# %%
import json

request = requests.get('https://api.github.com/events')
json.loads(request.text)
# Out:
# },
#  {'id': '10965941104',
#   'type': 'PushEvent',
#   'actor': {'id': 16780523,
#    'login': 'haxshaan',
#    'display_login': 'haxshaan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haxshaan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16780523?'},
#   'repo': {'id': 224104170,
#    'name': 'haxshaan/SnakesNLadders',
#    'url': 'https://api.github.com/repos/haxshaan/SnakesNLadders'},
#   'payload': {'push_id': 4330388489,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd878017a412a59c04a0ab1a2d5b3b018256080bd',
#    'before': 'd7fd6fd7b95f55c6e3c66689046a8d660d1d3a5c',
#    'commits': [{'sha': 'd878017a412a59c04a0ab1a2d5b3b018256080bd',
#      'author': {'email': 'shantam.m22@gmail.com', 'name': 'Shantam Mathuria'},
#      'message': 'Update main.py\n\nAdd a new line before first roll',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/haxshaan/SnakesNLadders/commits/d878017a412a59c04a0ab1a2d5b3b018256080bd'}]},
#   'public': True,
#   'created_at': '2019-11-28T05:11:11Z'},
#  {'id': '10965941103',
#   'type': 'PushEvent',
#   'actor': {'id': 48611241,
#    'login': 'dilanMD',
#    'display_login': 'dilanMD',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dilanMD',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48611241?'},
#   'repo': {'id': 222930114,
#    'name': 'dilanMD/Soccer',
#    'url': 'https://api.github.com/repos/dilanMD/Soccer'},
#   'payload': {'push_id': 4330388487,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c0ed85820e7cf67b2b30fcdb6f638e5040597729',
#    'before': 'c288e7739dc98357bce9b439a294c70f82dc4d9b',
#    'commits': [{'sha': 'c0ed85820e7cf67b2b30fcdb6f638e5040597729',
#      'author': {'email': 'deluxan.sgic@gmail.com', 'name': 'dilanMD'},
#      'message': 'News activity menu added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dilanMD/Soccer/commits/c0ed85820e7cf67b2b30fcdb6f638e5040597729'}]},
#   'public': True,
#   'created_at': '2019-11-28T05:11:11Z'},
#  {'id': '10965941093',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 32095923,
#    'login': 'Anurag810',
#    'display_login': 'Anurag810',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Anurag810',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32095923?'},
#   'repo': {'id': 1864233,
#    'name': 'frappe/erpnext',
#    'url': 'https://api.github.com/repos/frappe/erpnext'},
#   'payload': {'action': 'opened',
#    'number': 19719,
#    'pull_request': {'url': 'https://api.github.com/repos/frappe/erpnext/pulls/19719',
#     'id': 346524250,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NTI0MjUw',
#     'html_url': 'https://github.com/frappe/erpnext/pull/19719',
#     'diff_url': 'https://github.com/frappe/erpnext/pull/19719.diff',
#     'patch_url': 'https://github.com/frappe/erpnext/pull/19719.patch',
#     'issue_url': 'https://api.github.com/repos/frappe/erpnext/issues/19719',
#     'number': 19719,
#     'state': 'open',
#     'locked': False,
#     'title': 'fix: added bank reconciliation page in the accounting module',
#     'user': {'login': 'Anurag810',
#      'id': 32095923,
#      'node_id': 'MDQ6VXNlcjMyMDk1OTIz',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/32095923?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Anurag810',
#      'html_url': 'https://github.com/Anurag810',
#      'followers_url': 'https://api.github.com/users/Anurag810/followers',
#      'following_url': 'https://api.github.com/users/Anurag810/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Anurag810/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Anurag810/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Anurag810/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Anurag810/orgs',
#      'repos_url': 'https://api.github.com/users/Anurag810/repos',
#      'events_url': 'https://api.github.com/users/Anurag810/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Anurag810/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '\r\nadded bank reconciliation page in the accounting module',
#     'created_at': '2019-11-28T05:11:10Z',
#     'updated_at': '2019-11-28T05:11:10Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/frappe/erpnext/pulls/19719/commits',
#     'review_comments_url': 'https://api.github.com/repos/frappe/erpnext/pulls/19719/comments',
#     'review_comment_url': 'https://api.github.com/repos/frappe/erpnext/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/frappe/erpnext/issues/19719/comments',
#     'statuses_url': 'https://api.github.com/repos/frappe/erpnext/statuses/d9f803d6000f2568b4301d6b2fc33490421889f3',
#     'head': {'label': 'Anurag810:added_page_bank_reconcilation_added',
#      'ref': 'added_page_bank_reconcilation_added',
#      'sha': 'd9f803d6000f2568b4301d6b2fc33490421889f3',
#      'user': {'login': 'Anurag810',
#       'id': 32095923,
#       'node_id': 'MDQ6VXNlcjMyMDk1OTIz',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/32095923?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Anurag810',
#       'html_url': 'https://github.com/Anurag810',
#       'followers_url': 'https://api.github.com/users/Anurag810/followers',
#       'following_url': 'https://api.github.com/users/Anurag810/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Anurag810/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Anurag810/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Anurag810/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Anurag810/orgs',
#       'repos_url': 'https://api.github.com/users/Anurag810/repos',
#       'events_url': 'https://api.github.com/users/Anurag810/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Anurag810/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 158689773,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTg2ODk3NzM=',
#       'name': 'erpnext',
#       'full_name': 'Anurag810/erpnext',
#       'private': False,
#       'owner': {'login': 'Anurag810',
#        'id': 32095923,
#        'node_id': 'MDQ6VXNlcjMyMDk1OTIz',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/32095923?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Anurag810',
#        'html_url': 'https://github.com/Anurag810',
#        'followers_url': 'https://api.github.com/users/Anurag810/followers',
#        'following_url': 'https://api.github.com/users/Anurag810/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Anurag810/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Anurag810/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Anurag810/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Anurag810/orgs',
#        'repos_url': 'https://api.github.com/users/Anurag810/repos',
#        'events_url': 'https://api.github.com/users/Anurag810/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Anurag810/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Anurag810/erpnext',
#       'description': 'Open Source ERP built for the web',
#       'fork': True,
#       'url': 'https://api.github.com/repos/Anurag810/erpnext',
#       'forks_url': 'https://api.github.com/repos/Anurag810/erpnext/forks',
#       'keys_url': 'https://api.github.com/repos/Anurag810/erpnext/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Anurag810/erpnext/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Anurag810/erpnext/teams',
#       'hooks_url': 'https://api.github.com/repos/Anurag810/erpnext/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Anurag810/erpnext/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Anurag810/erpnext/events',
#       'assignees_url': 'https://api.github.com/repos/Anurag810/erpnext/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Anurag810/erpnext/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Anurag810/erpnext/tags',
#       'blobs_url': 'https://api.github.com/repos/Anurag810/erpnext/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Anurag810/erpnext/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Anurag810/erpnext/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Anurag810/erpnext/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Anurag810/erpnext/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Anurag810/erpnext/languages',
#       'stargazers_url': 'https://api.github.com/repos/Anurag810/erpnext/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Anurag810/erpnext/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Anurag810/erpnext/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Anurag810/erpnext/subscription',
#       'commits_url': 'https://api.github.com/repos/Anurag810/erpnext/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Anurag810/erpnext/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Anurag810/erpnext/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Anurag810/erpnext/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Anurag810/erpnext/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Anurag810/erpnext/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Anurag810/erpnext/merges',
#       'archive_url': 'https://api.github.com/repos/Anurag810/erpnext/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Anurag810/erpnext/downloads',
#       'issues_url': 'https://api.github.com/repos/Anurag810/erpnext/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Anurag810/erpnext/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Anurag810/erpnext/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Anurag810/erpnext/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Anurag810/erpnext/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Anurag810/erpnext/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Anurag810/erpnext/deployments',
#       'created_at': '2018-11-22T11:31:51Z',
#       'updated_at': '2019-06-17T08:46:10Z',
#       'pushed_at': '2019-11-28T05:10:03Z',
#       'git_url': 'git://github.com/Anurag810/erpnext.git',
#       'ssh_url': 'git@github.com:Anurag810/erpnext.git',
#       'clone_url': 'https://github.com/Anurag810/erpnext.git',
#       'svn_url': 'https://github.com/Anurag810/erpnext',
#       'homepage': 'http://erpnext.com',
#       'size': 806018,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': 'develop'}},
#     'base': {'label': 'frappe:develop',
#      'ref': 'develop',
#      'sha': '638abca4988c164cf87c68a4a7fd382fae1027dd',
#      'user': {'login': 'frappe',
#       'id': 836974,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgzNjk3NA==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/836974?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/frappe',
#       'html_url': 'https://github.com/frappe',
#       'followers_url': 'https://api.github.com/users/frappe/followers',
#       'following_url': 'https://api.github.com/users/frappe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/frappe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/frappe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/frappe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/frappe/orgs',
#       'repos_url': 'https://api.github.com/users/frappe/repos',
#       'events_url': 'https://api.github.com/users/frappe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/frappe/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 1864233,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODY0MjMz',
#       'name': 'erpnext',
#       'full_name': 'frappe/erpnext',
#       'private': False,
#       'owner': {'login': 'frappe',
#        'id': 836974,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgzNjk3NA==',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/836974?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/frappe',
#        'html_url': 'https://github.com/frappe',
#        'followers_url': 'https://api.github.com/users/frappe/followers',
#        'following_url': 'https://api.github.com/users/frappe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/frappe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/frappe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/frappe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/frappe/orgs',
#        'repos_url': 'https://api.github.com/users/frappe/repos',
#        'events_url': 'https://api.github.com/users/frappe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/frappe/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/frappe/erpnext',
#       'description': 'Open Source Alternative to SAP',
#       'fork': False,
#       'url': 'https://api.github.com/repos/frappe/erpnext',
#       'forks_url': 'https://api.github.com/repos/frappe/erpnext/forks',
#       'keys_url': 'https://api.github.com/repos/frappe/erpnext/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/frappe/erpnext/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/frappe/erpnext/teams',
#       'hooks_url': 'https://api.github.com/repos/frappe/erpnext/hooks',
#       'issue_events_url': 'https://api.github.com/repos/frappe/erpnext/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/frappe/erpnext/events',
#       'assignees_url': 'https://api.github.com/repos/frappe/erpnext/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/frappe/erpnext/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/frappe/erpnext/tags',
#       'blobs_url': 'https://api.github.com/repos/frappe/erpnext/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/frappe/erpnext/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/frappe/erpnext/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/frappe/erpnext/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/frappe/erpnext/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/frappe/erpnext/languages',
#       'stargazers_url': 'https://api.github.com/repos/frappe/erpnext/stargazers',
#       'contributors_url': 'https://api.github.com/repos/frappe/erpnext/contributors',
#       'subscribers_url': 'https://api.github.com/repos/frappe/erpnext/subscribers',
#       'subscription_url': 'https://api.github.com/repos/frappe/erpnext/subscription',
#       'commits_url': 'https://api.github.com/repos/frappe/erpnext/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/frappe/erpnext/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/frappe/erpnext/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/frappe/erpnext/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/frappe/erpnext/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/frappe/erpnext/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/frappe/erpnext/merges',
#       'archive_url': 'https://api.github.com/repos/frappe/erpnext/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/frappe/erpnext/downloads',
#       'issues_url': 'https://api.github.com/repos/frappe/erpnext/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/frappe/erpnext/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/frappe/erpnext/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/frappe/erpnext/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/frappe/erpnext/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/frappe/erpnext/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/frappe/erpnext/deployments',
#       'created_at': '2011-06-08T08:20:56Z',
#       'updated_at': '2019-11-27T15:33:50Z',
#       'pushed_at': '2019-11-28T05:01:57Z',
#       'git_url': 'git://github.com/frappe/erpnext.git',
#       'ssh_url': 'git@github.com:frappe/erpnext.git',
#       'clone_url': 'https://github.com/frappe/erpnext.git',
#       'svn_url': 'https://github.com/frappe/erpnext',
#       'homepage': 'https://erpnext.com',
#       'size': 805569,
#       'stargazers_count': 5378,
#       'watchers_count': 5378,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2365,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2170,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 2365,
#       'open_issues': 2170,
#       'watchers': 5378,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/frappe/erpnext/pulls/19719'},
#      'html': {'href': 'https://github.com/frappe/erpnext/pull/19719'},
#      'issue': {'href': 'https://api.github.com/repos/frappe/erpnext/issues/19719'},
#      'comments': {'href': 'https://api.github.com/repos/frappe/erpnext/issues/19719/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/frappe/erpnext/pulls/19719/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/frappe/erpnext/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/frappe/erpnext/pulls/19719/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/frappe/erpnext/statuses/d9f803d6000f2568b4301d6b2fc33490421889f3'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-11-28T05:11:11Z',
#   'org': {'id': 836974,
#    'login': 'frappe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/frappe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/836974?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import json

request = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(request.text)
# Out:
# ade feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1290f1c57001592f12a',
#    'type': 'cat',
#    'text': 'Bobtail cats owe their shortened tails to a natural genetic mutation that has appeared in cats across time and in various regions of the world. The American Bobtail can be traced back to Yodi, a cat with the mutation that was found in Arizona in the 1960s. Yodi passed the genetic quirk on to his kittens, thus creating a new breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
import json

request = requests.get('https://wakatime.com/api/v1/')
print(json.loads(request.text))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-20-d476ee4b1089> in <module>
#       2
#       3 request = requests.get('https://api.abuseipdb.com/api/v2/blacklist')
# ----> 4 print(json.loads(request.text))
#
# C:\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# C:\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
